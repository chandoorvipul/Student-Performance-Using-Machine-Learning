# %%
import pandas as pd
dataset = pd.read_csv("StudentsPerformance.csv")
print(dataset)
# Out:
#      gender race/ethnicity      ...      reading score writing score
# 0    female        group B      ...                 72            74
# 1    female        group C      ...                 90            88
# 2    female        group B      ...                 95            93
# 3      male        group A      ...                 57            44
# 4      male        group C      ...                 78            75
# 5    female        group B      ...                 83            78
# 6    female        group B      ...                 95            92
# 7      male        group B      ...                 43            39
# 8      male        group D      ...                 64            67
# 9    female        group B      ...                 60            50
# 10     male        group C      ...                 54            52
# 11     male        group D      ...                 52            43
# 12   female        group B      ...                 81            73
# ...

# %% [markdown]
# ## Did you discover interesting relations?
#
# 1. This data set is the performance of the students.
# 2. We can see student marks which will be related to the parents level of Education.
# 3. We can also see students meal, how they prefer based on the gender.

# %% [markdown]
# ## What feature/s would you like to be able to predict?
#
# 1. We can caluclate the average of all scores of the student so that we can grade the student easily.
# 2. We can caluclate the average of the three subjects and all also the performance of the student in the exam based on parential level of education.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# gender                         1000 non-null object
# race/ethnicity                 1000 non-null object
# parental level of education    1000 non-null object
# lunch                          1000 non-null object
# test preparation course        1000 non-null object
# math score                     1000 non-null int64
# reading score                  1000 non-null int64
# writing score                  1000 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
dataset_copy = dataset.copy()
dataset_copy.drop(labels ='parental level of education', axis='columns', inplace=True)
print(dataset_copy.head())
# Out:
#    gender race/ethnicity      ...      reading score writing score
# 0  female        group B      ...                 72            74
# 1  female        group C      ...                 90            88
# 2  female        group B      ...                 95            93
# 3    male        group A      ...                 57            44
# 4    male        group C      ...                 78            75
#
# [5 rows x 7 columns]

# %%
dataset_copy.dropna(axis='index', how='any', inplace=True)
print(dataset_copy.head())
# Out:
#    gender race/ethnicity      ...      reading score writing score
# 0  female        group B      ...                 72            74
# 1  female        group C      ...                 90            88
# 2  female        group B      ...                 95            93
# 3    male        group A      ...                 57            44
# 4    male        group C      ...                 78            75
#
# [5 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(dataset_copy, test_size=0.25, random_state = 123)
print(len(train_set))
print(len(test_set))
print(train_set.head())
print(test_set.head())
# Out:
# 750
# 250
#      gender race/ethnicity      ...      reading score writing score
# 894  female        group E      ...                 62            69
# 941  female        group D      ...                 91            96
# 285    male        group B      ...                 82            82
# 462  female        group E      ...                 70            76
# 370    male        group E      ...                 77            71
#
# [5 rows x 7 columns]
#      gender race/ethnicity      ...      reading score writing score
# 131    male        group C      ...                 37            40
# 203  female        group B      ...                 69            68
# 50     male        group E      ...                 55            48
# 585  female        group C      ...                 76            76
# 138  female        group C      ...                 66            67
#
# [5 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix 
attributes = ['math score','reading score', 'writing score' ]
scatter_matrix(dataset_copy[attributes])
plt.show()
